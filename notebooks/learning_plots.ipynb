# %%
import pandas as pd

# %%
Cleaned_Spotify_2024_Global_Streaming_Data = pd.read_csv("../data/Cleaned_Spotify_2024_Global_Streaming_Data.csv")

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\pek43\\projects\\learning_plots_peklein1\\notebooks'

# %%
df = Cleaned_Spotify_2024_Global_Streaming_Data

# %%
df.head()
# Out:
#          Country        Artist                    Album      Genre  \
# 0        Germany  Taylor Swift  1989 (Taylor's Version)      K-pop
# 1         Brazil    The Weeknd              After Hours        R&B
# 2  United States   Post Malone                   Austin  Reggaeton
# 3          Italy    Ed Sheeran        Autumn Variations      K-pop
# 4          Italy    Ed Sheeran        Autumn Variations        R&B
#
#    Release Year  Monthly Listeners (Millions)  Total Streams (Millions)  \
# 0          2020                         23.10                   3695.53
# 1          2023                         60.60                   2828.16
# 2          2019                         42.84                   1425.46
# 3          2019                         73.24                   2704.33
# 4          2019                          7.89                   3323.25
#
#    Total Hours Streamed (Millions)  Avg Stream Duration (Min) Platform Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          500 non-null    str
#  1   Artist                           500 non-null    str
#  2   Album                            500 non-null    str
#  3   Genre                            500 non-null    str
#  4   Release Year                     500 non-null    int64
#  5   Monthly Listeners (Millions)     500 non-null    float64
#  6   Total Streams (Millions)         500 non-null    float64
#  7   Total Hours Streamed (Millions)  500 non-null    float64
#  8   Avg Stream Duration (Min)        500 non-null    float64
#  9   Platform Type                    500 non-null    str
#  10  Streams Last 30 Days (Millions)  500 non-null    float64
#  11  Skip Rate (%)                    500 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Release Year  Monthly Listeners (Millions)  Total Streams (Millions)  \
# count    500.000000                     500.00000                500.000000
# mean    2020.630000                      51.04122               2581.154080
# std        1.723671                      28.23801               1416.055972
# min     2018.000000                       1.01000                 53.560000
# 25%     2019.000000                      27.67250               1337.337500
# 50%     2020.000000                      50.82500               2697.355000
# 75%     2022.000000                      75.09500               3798.197500
# max     2023.000000                      99.80000               4985.540000
#
#        Total Hours Streamed (Millions)  Avg Stream Duration (Min)  \
# count                       500.000000                 500.000000
# mean                       8954.368880                   3.520640
# std                        5167.648272                   0.571431
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.dropna()
# Out:
#            country        artist                    album      genre  \
# 0          Germany  Taylor Swift  1989 (Taylor's Version)      K-pop
# 1           Brazil    The Weeknd              After Hours        R&B
# 2    United States   Post Malone                   Austin  Reggaeton
# 3            Italy    Ed Sheeran        Autumn Variations      K-pop
# 4            Italy    Ed Sheeran        Autumn Variations        R&B
# ..             ...           ...                      ...        ...
# 495         Brazil       Karol G       MAÑANA SERÁ BONITO       Jazz
# 496         Canada      Dua Lipa         Future Nostalgia  Classical
# 497        Germany       Karol G       MAÑANA SERÁ BONITO       Rock
# 498         Canada           SZA                      SOS      Indie
# 499         Sweden           BTS                    Proof  Reggaeton
#
#      release_year  monthly_listeners_(millions)  total_streams_(millions)  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv("cleaned_file.csv", index=False)

# %%
grouped = df.groupby("artist")["monthly_listeners_(millions)"].mean()
grouped.plot(kind="bar")
# Out:
# <Axes: xlabel='artist'>

# %%
import matplotlib.pyplot as plt

plt.bar(grouped.index, grouped.values)
# Out:
# <BarContainer object of 15 artists>

# %%
plt.bar(grouped.index, grouped.values)

plt.xlabel("Category")
plt.ylabel("Average Value")
plt.title("Average Value by Category")

plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(
    grouped.index,
    grouped.values,
    color="skyblue",   # any named color or hex code
    width=0.6          # default is 0.8
)

plt.xlabel("Category")
plt.ylabel("Average Value")
plt.title("Average Value by Category")
plt.xticks(rotation=45)

plt.show()

# %%
df.dtypes
# Out:
# country                                str
# artist                                 str
# album                                  str
# genre                                  str
# release_year                         int64
# monthly_listeners_(millions)       float64
# total_streams_(millions)           float64
# total_hours_streamed_(millions)    float64
# avg_stream_duration_(min)          float64
# platform_type                          str
# streams_last_30_days_(millions)    float64
# skip_rate_(%)                      float64
# dtype: object

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

x = df["monthly_listeners_(millions)"]
y = df["total_streams_(millions)"]

plt.scatter(x, y)
plt.xlabel("Monthly listeners (millions)")
plt.ylabel("Total streams (millions)")
plt.title("Monthly listeners vs Total streams")
plt.show()
plt.show()

# %%
plt.scatter(x, y)

plt.xlabel("Numeric Column 1")
plt.ylabel("Numeric Column 2")
plt.title("Relationship Between Two Variables")
plt.scatter(
    x,
    y,
    s=80,          # point size
    color="purple",
    alpha=0.6      # transparency (0 = invisible, 1 = solid)
)

plt.xlabel("Numeric Column 1")
plt.ylabel("Numeric Column 2")
plt.title("Customized Scatter Plot")

plt.show()

# %%
import pandas as pd

# prefer existing dataframe, fall back to known csv paths
if "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
    df = Cleaned_Spotify_2024_Global_Streaming_Data.copy()
else:
    tried = False
    for p in (csv_path, str(csv_file), str(alt)):
        try:
            df = pd.read_csv(p)
            tried = True
            break
        except Exception:
            continue
    if not tried:
        raise FileNotFoundError("No data source found; define Cleaned_Spotify_2024_Global_Streaming_Data or ensure csv_path/csv_file/alt exist")

# ensure both column name styles are supported
if "release_year" in df.columns and "Release Year" not in df.columns:
    df["Release Year"] = df["release_year"]

# Ensure Release Year is numeric
df["Release Year"] = pd.to_numeric(df["Release Year"], errors="coerce")

# %%
yearly = df.groupby("Release Year")["total_streams_(millions)"].mean()
yearly
yearly
# Out:
# Release Year
# 2018    2611.255161
# 2019    2516.447241
# 2020    2569.617222
# 2021    2763.213243
# 2022    2367.991633
# 2023    2817.970849
# Name: total_streams_(millions), dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(yearly.index, yearly.values)
plt.show()
plt.plot(yearly.index, yearly.values)

plt.xlabel("Release Year")
plt.ylabel("Average Streams")
plt.title("Average Streams Over Time")

plt.show()
plt.plot(
    yearly.index,
    yearly.values,
    color="darkblue",
    linestyle="--",   # dashed line
    marker="o",       # circle markers
    markersize=6,
    linewidth=2
)

plt.xlabel("Release Year")
plt.ylabel("Average Streams")
plt.title("Average Streams Over Time")

plt.xticks(yearly.index, rotation=45)  # cleaner year labels

plt.show()

# %%
import pandas as pd

if "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
    df = Cleaned_Spotify_2024_Global_Streaming_Data
elif "csv_path" in globals():
    df = pd.read_csv(csv_path)
elif "csv_file" in globals():
    df = pd.read_csv(csv_file)
elif "alt" in globals():
    df = pd.read_csv(alt)
else:
    raise FileNotFoundError("No available dataframe or csv path defined")

cat = df["platform_type"]

# %%
counts = cat.value_counts()
counts
totals = df.groupby("platform_type")["total_streams_(millions)"].sum()
totals
import matplotlib.pyplot as plt

plt.pie(counts.values, labels=counts.index)
plt.show()
plt.pie(
    counts.values,
    labels=counts.index,
    autopct="%1.1f%%"   # show percentages
)

plt.title("Platform Distribution")
plt.show()
colors = ["#6A5ACD", "#FFB347", "#77DD77", "#FF6961", "#AEC6CF"]

plt.figure(figsize=(6, 6))

plt.pie(
    counts.values,
    labels=counts.index,
    autopct="%1.1f%%",
    colors=colors,
    startangle=90,     # rotate for better orientation
    wedgeprops={"edgecolor": "white"}  # clean separation lines
)

plt.title("Platform Distribution")
plt.tight_layout()
plt.show()

# %%
import pandas as pd

if "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
    df = Cleaned_Spotify_2024_Global_Streaming_Data
elif "csv_path" in globals():
    if "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
        df = Cleaned_Spotify_2024_Global_Streaming_Data
    elif "csv_path" in globals():
        df = pd.read_csv(csv_path)
    elif "csv_file" in globals():
        df = pd.read_csv(csv_file)
    elif "alt" in globals():
        df = pd.read_csv(alt)
    else:
        raise FileNotFoundError("No valid data source found")

    if "avg_stream_duration_(min)" in df.columns:
        x = df["avg_stream_duration_(min)"]
    elif "Stream Duration" in df.columns:
        x = df["Stream Duration"]
    else:
        raise KeyError("No valid duration column found in dataframe")

# %%
import matplotlib.pyplot as plt

plt.hist(x)
plt.show()
plt.hist(x, bins=20)   # try 10, 20, 30 to see differences
plt.show()
plt.hist(x, bins=20)

plt.xlabel("Stream Duration (seconds)")
plt.ylabel("Count")
plt.title("Distribution of Stream Duration")

plt.show()
plt.hist(
    x,
    bins=20,
    color="skyblue",
    alpha=0.7,          # transparency
    edgecolor="black",  # outline each bar
    linewidth=1
)

plt.xlabel("Stream Duration (seconds)")
plt.ylabel("Count")
plt.title("Distribution of Stream Duration")

plt.show()

# %%
import pandas as pd

# prefer an existing dataframe, fall back to known csv paths/variables
if "df" in globals() and isinstance(df, pd.DataFrame):
    pass
elif "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
    df = Cleaned_Spotify_2024_Global_Streaming_Data
else:
    for var in ("csv_path", "csv_file", "alt"):
        if var in globals():
            try:
                df = pd.read_csv(globals()[var])
                break
            except Exception:
                continue
    else:
        raise FileNotFoundError("No dataframe found; define df or provide csv_path/csv_file/alt")

for col in ["skip_rate_(%)", "Skip Rate", "skip_rate", "Skip Rate (%)"]:
    if col in df.columns:
        numeric = df[col]
        break
else:
    raise KeyError("No skip rate column found in dataframe")
for cname in ("Platform", "platform", "platform_type", "Platform Type", "platform type"):
    if cname in df.columns:
        category = df[cname]
        break
else:
    raise KeyError("No platform column found in dataframe")

# create canonical column names so later direct indexing won't KeyError
df["Skip Rate"] = df[col]
df["Platform"] = df[cname]
numeric = pd.to_numeric(df["Skip Rate"], errors="coerce")
category = df["Platform"]          # or Genre, Region, etc.

# %%
groups = [numeric[category == c] for c in category.unique()]
labels = category.unique()
import matplotlib.pyplot as plt

plt.boxplot(groups, labels=labels)
plt.show()
plt.figure(figsize=(8, 5))

plt.boxplot(
    groups,
    labels=labels,
    patch_artist=True,          # allows color fill
    boxprops=dict(facecolor="skyblue"),
    medianprops=dict(color="red", linewidth=2),
)

plt.xticks(rotation=45)
plt.xlabel("Platform")
plt.ylabel("Skip Rate")
plt.title("Skip Rate Distribution by Platform")

plt.show()
# Out:
# C:\Users\pek43\AppData\Local\Temp\ipykernel_48008\2394592322.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\pek43\AppData\Local\Temp\ipykernel_48008\2394592322.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
import pandas as pd

# prefer existing dataframe or known paths instead of "yourfile.csv"
if "df" in globals() and isinstance(df, pd.DataFrame):
    pass
elif "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
    df = Cleaned_Spotify_2024_Global_Streaming_Data
elif "csv_path" in globals():
    df = pd.read_csv(csv_path)
elif "csv_file" in globals():
    df = pd.read_csv(csv_file)
elif "alt" in globals():
    df = pd.read_csv(alt)
else:
    raise FileNotFoundError("No data source found; define df or provide csv_path/csv_file/alt")

corr = df.corr(numeric_only=True)
corr
# Out:
#                                  release_year  monthly_listeners_(millions)  \
# release_year                         1.000000                      0.055194
# monthly_listeners_(millions)         0.055194                      1.000000
# total_streams_(millions)             0.040770                      0.016523
# total_hours_streamed_(millions)      0.028361                      0.016477
# avg_stream_duration_(min)            0.055969                      0.044256
# streams_last_30_days_(millions)      0.060606                      0.049882
# skip_rate_(%)                       -0.019525                      0.011846
# Skip Rate                           -0.019525                      0.011846
#
#                                  total_streams_(millions)  \
# release_year                                     0.040770
# monthly_listeners_(millions)                     0.016523
# total_streams_(millions)                         1.000000
# ...

# %%
plt.matshow(corr, cmap="coolwarm")
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.imshow(corr, cmap="coolwarm", interpolation="nearest")
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()
plt.figure(figsize=(9, 7))

plt.imshow(corr, cmap="coolwarm")
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha="right")
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Heatmap", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

if "df" not in globals():
    if "Cleaned_Spotify_2024_Global_Streaming_Data" in globals():
        df = Cleaned_Spotify_2024_Global_Streaming_Data
    elif "csv_path" in globals():
        df = pd.read_csv(csv_path)
    elif "csv_file" in globals():
        df = pd.read_csv(csv_file)
    elif "alt" in globals():
        df = pd.read_csv(alt)
    else:
        raise FileNotFoundError("No data source found; define df or provide csv_path/csv_file/alt")

cat = df["Platform"]   # or Genre, Region, etc.

cat = df["Platform"]   # or Genre, Region, etc.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("yourfile.csv")
#       5 cat = df["Platform"]   # or Genre, Region, etc.
#
# File c:\Users\pek43\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
